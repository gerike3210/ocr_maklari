# %%
import matplotlib.pyplot as plt

import keras_ocr

# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()

# Get a set of three example images
images = [
    keras_ocr.tools.read(img) for img in [
        './img2.jpg'
    ]
]

# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)
print(prediction_groups)
# # Plot the predictions
# fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
# for ax, image, predictions in zip(axs, images, prediction_groups):
#     keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# Looking for /Users/fulopgergely/.keras-ocr/craft_mlt_25k.h5
# Looking for /Users/fulopgergely/.keras-ocr/crnn_kurapan.h5
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd37f3bdc60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 15s 15s/step
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd37f3bdd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 10s 497ms/step
# [[('nagyreszben', array([[338.75433  ,  13.424728 ],
#        [515.05853  ,   2.2053795],
#        [517.1247   ,  34.673893 ],
#        [340.8205   ,  45.89324  ]], dtype=float32)), ('groltenteils', array([[ 16.96181 ,  12.977196],
#        [197.36139 ,   4.068573],
#        [198.97794 ,  36.80356 ],
#        [ 18.578354,  45.71218 ]], dtype=float32)), ('emesztetlen', array([[340.,  50.],
#        [507.,  50.],
#        [507.,  78.],
#        [340.,  78.]], dtype=float32)), ('unverdaut', array([[ 20.,  52.],
#        [178.,  52.],
#        [178.,  80.],
#        [ 20.,  80.]], dtype=float32)), ('ehezni', array([[341.,  92.],
#        [433.,  92.],
#        [433., 119.],
#        [341., 119.]], dtype=float32)), ('hungern', array([[ 20.256931,  95.4633  ],
#        [147.58623 ,  99.804085],
#        [146.54999 , 130.20058 ],
#        [ 19.220692, 125.859795]], dtype=float32)), ('utan', array([[402.     , 131.99998],
#        [465.     , 131.99998],
#        [465.     , 159.99998],
#        [402.     , 159.99998]], dtype=float32)), ('kutat', array([[471., 132.],
#        [545., 132.],
#        [545., 159.],
#        [471., 159.]], dtype=float32)), ('nachtd', array([[130.55939, 136.07243],
#        [247.80219, 133.60414],
#        [248.37524, 160.82365],
#        [131.13245, 163.29195]], dtype=float32)), ('vmi', array([[341.02457, 136.44307],
#        [395.79996, 133.39998],
#        [397.21536, 158.8769 ],
#        [342.43997, 161.92   ]], dtype=float32)), ('suchen', array([[ 19., 136.],
#        [123., 136.],
#        [123., 163.],
#        [ 19., 163.]], dtype=float32)), ('lap', array([[458., 173.],
#        [504., 173.],
#        [504., 208.],
#        [458., 208.]], dtype=float32)), ('mocsar', array([[343.68304, 171.29056],
#        [452.30377, 176.01321],
#        [450.93964, 207.38867],
#        [342.3189 , 202.66602]], dtype=float32)), ('sumpf', array([[ 42., 176.],
#        [146., 176.],
#        [146., 210.],
#        [ 42., 210.]], dtype=float32)), ('t', array([[ 20., 184.],
#        [ 37., 184.],
#        [ 37., 203.],
#        [ 20., 203.]], dtype=float32)), ('jobbfan', array([[338.2423 , 216.97453],
#        [461.76202, 213.51137],
#        [462.72607, 247.89555],
#        [339.20636, 251.35872]], dtype=float32)), ('besser', array([[ 22., 220.],
#        [115., 220.],
#        [115., 247.],
#        [ 22., 247.]], dtype=float32)), ('emesztheto', array([[341.65454, 259.50507],
#        [499.885  , 257.17816],
#        [500.3047 , 285.71613],
#        [342.07422, 288.04303]], dtype=float32)), ('verdaulich', array([[ 21., 261.],
#        [180., 261.],
#        [180., 288.],
#        [ 21., 288.]], dtype=float32)), ('puha', array([[337.84393, 306.48553],
#        [409.2312 , 295.50287],
#        [414.1098 , 327.21387],
#        [342.72253, 338.19653]], dtype=float32)), ('weich', array([[ 22., 304.],
#        [107., 304.],
#        [107., 331.],
#        [ 22., 331.]], dtype=float32)), ('mikozben', array([[414.58075, 342.72827],
#        [553.7518 , 340.2207 ],
#        [554.26666, 368.797  ],
#        [415.09564, 371.30457]], dtype=float32)), ('migs', array([[345.08734, 340.34494],
#        [410.19653, 349.02615],
#        [406.09174, 379.81216],
#        [340.98254, 371.13095]], dtype=float32)), ('wobei', array([[ 21.62226 , 346.846   ],
#        [108.9337  , 345.28687 ],
#        [109.42429 , 372.76025 ],
#        [ 22.112854, 374.3194  ]], dtype=float32)), ('szandek', array([[341.70868, 383.82278],
#        [459.89636, 382.39883],
#        [460.25226, 411.93674],
#        [342.06458, 413.3607 ]], dtype=float32)), ('albsicht', array([[ 47., 387.],
#        [162., 387.],
#        [162., 414.],
#        [ 47., 414.]], dtype=float32)), ('e', array([[ 20., 394.],
#        [ 38., 394.],
#        [ 38., 414.],
#        [ 20., 414.]], dtype=float32)), ('iszap', array([[344.32028, 427.27594],
#        [427.69974, 432.92877],
#        [425.7598 , 461.54303],
#        [342.38034, 455.8902 ]], dtype=float32)), ('sar', array([[432., 428.],
#        [478., 428.],
#        [478., 454.],
#        [432., 454.]], dtype=float32)), ('schlamm', array([[ 44., 429.],
#        [185., 429.],
#        [185., 457.],
#        [ 44., 457.]], dtype=float32)), ('r', array([[ 21., 435.],
#        [ 38., 435.],
#        [ 38., 455.],
#        [ 21., 455.]], dtype=float32)), ('elsullyedni', array([[342.60147, 468.08002],
#        [498.80435, 465.24   ],
#        [499.43326, 499.82855],
#        [343.23038, 502.66858]], dtype=float32)), ('versinken', array([[ 22., 471.],
#        [168., 471.],
#        [168., 498.],
#        [ 22., 498.]], dtype=float32)), ('aiul', array([[175., 471.],
#        [250., 471.],
#        [250., 497.],
#        [175., 497.]], dtype=float32))]]
